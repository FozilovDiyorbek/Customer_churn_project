# %%
import pandas as pd
import numpy as np
import os

df = pd.read_csv("C:/Projects/Customer_churn_project/data/raw/customer_churn.csv")
print("Duplicated rows:", df.duplicated().sum())
df.info()
# Out:
# Duplicated rows: 0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               15000 non-null  int64
#  1   CustomerId       15000 non-null  float64
#  2   Surname          15000 non-null  object
#  3   CreditScore      15000 non-null  float64
#  4   Geography        15000 non-null  object
#  5   Gender           15000 non-null  object
#  6   Age              15000 non-null  float64
#  7   Tenure           15000 non-null  float64
#  8   Balance          15000 non-null  float64
#  9   NumOfProducts    15000 non-null  float64
#  10  HasCrCard        15000 non-null  float64
#  11  IsActiveMember   15000 non-null  float64
#  12  EstimatedSalary  15000 non-null  float64
#  13  Exited           15000 non-null  float64
# dtypes: float64(10), int64(1), object(3)
# memory usage: 1.6+ MB

# %%
columns_to_drop = ["id", "CustomerId", "Surname"]
df = df.drop(columns=columns_to_drop, errors='ignore')
df
# Out:
#        CreditScore Geography  Gender   Age  Tenure    Balance  NumOfProducts  \
# 0            567.0    France    Male  33.0     9.0       0.00            2.0
# 1            628.0    France  Female  38.0     3.0       0.00            1.0
# 2            635.0    France  Female  29.0     3.0       0.00            2.0
# 3            681.0    France    Male  28.0     6.0       0.00            2.0
# 4            587.0    France  Female  27.0     5.0       0.00            2.0
# ...            ...       ...     ...   ...     ...        ...            ...
# 14995        581.0    France    Male  35.0     1.0       0.00            2.0
# 14996        806.0   Germany    Male  42.0     1.0  129120.64            2.0
# 14997        620.0    France  Female  29.0     7.0       0.00            2.0
# 14998        622.0   Germany    Male  51.0     6.0  106070.89            3.0
# 14999        543.0    France    Male  36.0     8.0       0.00            1.0
#
# ...

# %%
os.makedirs("C:\Projects\Customer_churn_project\data\processed", exist_ok=True)
df.to_csv("C:\Projects\Customer_churn_project\data\processed\cleaned_customer_churn.csv", index=False)
print("Cleaned dataset saved: data/processed/cleaned_customer_churn.csv")
# Out:
# Cleaned dataset saved: data/processed/cleaned_customer_churn.csv
